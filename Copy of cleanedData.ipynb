# %%
# Import Libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
test = pd.read_csv('/content/drive/MyDrive/BTAI (1)/tweetsum_test.csv')
train = pd.read_csv('/content/drive/MyDrive/BTAI (1)/tweetsum_train.csv')
val = pd.read_csv('/content/drive/MyDrive/BTAI (1)/tweetsum_val.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train.head()
test.head()
val.head()
# Out:
#    Unnamed: 0                         dialog_id  annot_id    sender  \
# 0           0  caae83a2ed59e4959d814ea567980226         0  customer
# 1           1  caae83a2ed59e4959d814ea567980226         1  customer
# 2           2  caae83a2ed59e4959d814ea567980226         2  customer
# 3           3  caae83a2ed59e4959d814ea567980226         0  customer
# 4           4  caae83a2ed59e4959d814ea567980226         1  customer
#
#                                             sentence  is_salient
# 0  @SpotifyCares hey, any explanation why the "Cr...        True
# 1  @SpotifyCares hey, any explanation why the "Cr...        True
# 2  @SpotifyCares hey, any explanation why the "Cr...        True
# 3                    MacBook, v1.0.64.399.g4637b02a.       False
# 4                    MacBook, v1.0.64.399.g4637b02a.       False

# %%
# Function - copy this to use the cleaned data in your file
def clean(test,train,val):
  # Col for Word Count
  train['word_count']=train['sentence'].apply(lambda x:len(x.split()))
  test['word_count']=test['sentence'].apply(lambda x:len(x.split()))
  val['word_count']=val['sentence'].apply(lambda x:len(x.split()))

  #adding a new column to X_train "is_question" that flags true for question senteces and false for non-question sentences
  question_words = ["who", "what", "when", "where", "why", "how", "if"]
  train['is_question'] = (train['sentence'].str.endswith('?') | train['sentence'].str.lower().str.contains(fr'\b(?:{"|".join(question_words)})\b'))
  test['is_question'] = (train['sentence'].str.endswith('?') | train['sentence'].str.lower().str.contains(fr'\b(?:{"|".join(question_words)})\b'))
  val['is_question'] = (train['sentence'].str.endswith('?') | train['sentence'].str.lower().str.contains(fr'\b(?:{"|".join(question_words)})\b'))

  # # Drop sender, annot_id, dialog_id, and Unnamed: 0
  # train.drop(['sender', 'annot_id', 'dialog_id', 'Unnamed: 0'], axis = 1, inplace = True)
  # test.drop(['sender', 'annot_id', 'dialog_id', 'Unnamed: 0'], axis = 1, inplace = True)
  # val.drop(['sender', 'annot_id', 'dialog_id', 'Unnamed: 0'], axis = 1, inplace = True)

  return test,train,val

# %%
train, test, val = clean(train, test, val)

# %%
# Export CSV
import csv
train.to_csv('train.csv', index=False)
test.to_csv('test.csv', index=False)
val.to_csv('val.csv', index=False)
# saved to "files" tab

# %%
test = pd.read_csv('test.csv')
test.head(15)
# Out:
#     Unnamed: 0                         dialog_id  annot_id    sender  \
# 0            0  bbde6d8ec7c39c4551da1ff6024f997b         0  customer
# 1            1  bbde6d8ec7c39c4551da1ff6024f997b         1  customer
# 2            2  bbde6d8ec7c39c4551da1ff6024f997b         2  customer
# 3            3  bbde6d8ec7c39c4551da1ff6024f997b         0  customer
# 4            4  bbde6d8ec7c39c4551da1ff6024f997b         1  customer
# 5            5  bbde6d8ec7c39c4551da1ff6024f997b         2  customer
# 6            6  bbde6d8ec7c39c4551da1ff6024f997b         0     agent
# 7            7  bbde6d8ec7c39c4551da1ff6024f997b         1     agent
# 8            8  bbde6d8ec7c39c4551da1ff6024f997b         2     agent
# 9            9  bbde6d8ec7c39c4551da1ff6024f997b         0     agent
# 10          10  bbde6d8ec7c39c4551da1ff6024f997b         1     agent
# 11          11  bbde6d8ec7c39c4551da1ff6024f997b         2     agent
# 12          12  bbde6d8ec7c39c4551da1ff6024f997b         0     agent
# 13          13  bbde6d8ec7c39c4551da1ff6024f997b         1     agent
# 14          14  bbde6d8ec7c39c4551da1ff6024f997b         2     agent
#
#                                              sentence  is_salient  word_count  \
# 0   @hulu_support My watchlist is not updating wit...        True          12
# 1   @hulu_support My watchlist is not updating wit...        True          12
# 2   @hulu_support My watchlist is not updating wit...        True          12
# 3                                       Any idea why?       False           3
# 4                                       Any idea why?       False           3
# 5                                       Any idea why?       False           3
# 6         @658975 Apologies for the trouble, Norlene!       False           6
# 7         @658975 Apologies for the trouble, Norlene!       False           6
# 8         @658975 Apologies for the trouble, Norlene!       False           6
# 9                            We're looking into this.       False           4
# 10                           We're looking into this.       False           4
# 11                           We're looking into this.       False           4
# 12  In the meantime, try navigating to the season ...       False          11
# 13  In the meantime, try navigating to the season ...        True          11
# 14  In the meantime, try navigating to the season ...        True          11
#
#     is_question
# 0         False
# 1         False
# 2         False
# 3          True
# 4          True
# 5          True
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
